# %%
import pandas as pd

pd.read_excel('Book2.xlsx')

# %%
pd[unit_of_measurement = ft]

# %%
pd[unit_of_measurement == ft]

# %%
df = pd.read_excel('Book2.xlsx')

# %%
import pandas as pd

df = pd.read_excel('Book2.xlsx')

# %%
print(df)

# %%
df[unit_of_measurement == ft]

# %%
df[unit_of_measurement == ft]

# %%
import pandas as pd
df = pd.read_excel('Book2.xlsx',
header=0,
index_col=False,
keep_default_na=True
)

# %%
print(df)

# %%
df.head

# %%
df[Moisture]

# %%
import pandas as pd
df = pd.read_excel('Book2.xlsx',
header=0,
keep_default_na=True
)

# %%
df[0,0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# D:\Anaconda\envs\pandas\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: (0, 0)
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-2-262bebbf33ce> in <module>
# ----> 1 df[0,0]
#
# ...

# %%
df.head
# Out:
# <bound method NDFrame.head of       Place Country.of.Origin       Altitude                           Region  \
# 0         1          Ethiopia      1950-2200                     guji-hambela
# 1         2          Ethiopia      1950-2200                     guji-hambela
# 2         3         Guatemala  1600 - 1800 m                              NaN
# 3         4          Ethiopia      1800-2200                           oromia
# 4         5          Ethiopia      1950-2200                     guji-hambela
# ...     ...               ...            ...                              ...
# 1301   1303          Honduras      1450 msnm                          marcala
# 1302   1304            Mexico            900               juchique de ferrer
# 1303   1305             Haiti          ~350m  department d'artibonite , haiti
# 1304   1306         Nicaragua           1100                           jalapa
# 1305   1307         Guatemala           4650                    nuevo oriente
#
# ...

# %%
df['Place']
# Out:
# 0          1
# 1          2
# 2          3
# 3          4
# 4          5
#         ...
# 1301    1303
# 1302    1304
# 1303    1305
# 1304    1306
# 1305    1307
# Name: Place, Length: 1306, dtype: int64

# %%
df['Moisture']
# Out:
# 0       0.12
# 1       0.12
# 2       0.00
# 3       0.11
# 4       0.12
#         ...
# 1301    0.10
# 1302    0.11
# 1303    0.14
# 1304    0.13
# 1305    0.10
# Name: Moisture, Length: 1306, dtype: float64

# %%
df['Altitude']
# Out:
# 0           1950-2200
# 1           1950-2200
# 2       1600 - 1800 m
# 3           1800-2200
# 4           1950-2200
#             ...
# 1301        1450 msnm
# 1302              900
# 1303            ~350m
# 1304             1100
# 1305             4650
# Name: Altitude, Length: 1306, dtype: object

# %%
df['unit_of_measurement' == "ft"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# D:\Anaconda\envs\pandas\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: False
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-e305525bb2c3> in <module>
# ...

# %%
df.set_index('Place')
# Out:
#       Country.of.Origin       Altitude                           Region  \
# Place
# 1              Ethiopia      1950-2200                     guji-hambela
# 2              Ethiopia      1950-2200                     guji-hambela
# 3             Guatemala  1600 - 1800 m                              NaN
# 4              Ethiopia      1800-2200                           oromia
# 5              Ethiopia      1950-2200                     guji-hambela
# ...                 ...            ...                              ...
# 1303           Honduras      1450 msnm                          marcala
# 1304             Mexico            900               juchique de ferrer
# 1305              Haiti          ~350m  department d'artibonite , haiti
# 1306          Nicaragua           1100                           jalapa
# 1307          Guatemala           4650                    nuevo oriente
#
#                        In.Country.Partner Harvest.Year          Grading.Date  \
# Place
# ...

# %%
df['unit_of_measurement']
# Out:
# 0        m
# 1        m
# 2        m
# 3        m
# 4        m
#         ..
# 1301     m
# 1302     m
# 1303     m
# 1304     m
# 1305    ft
# Name: unit_of_measurement, Length: 1306, dtype: object

# %%
df['unit_of_measurement' != 'm']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# D:\Anaconda\envs\pandas\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: True
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-bd7631301005> in <module>
# ...

# %%
sub = 'ft'
df['unit_of_measurement' = sub]
# Out:
#   File "<ipython-input-14-8fa121c9c5f3>", line 2
#     df['unit_of_measurement' = sub]
#                              ^
# SyntaxError: invalid syntax

# %%
sub = 'ft'
df['unit_of_measurement' == sub]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# D:\Anaconda\envs\pandas\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: False
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-2313157e9a7a> in <module>
#       1 sub = 'ft'
# ...

# %%
df = df[df.unit_of_measurement != 'ft']

# %%
df['unit_of_measurement']
# Out:
# 0       m
# 1       m
# 2       m
# 3       m
# 4       m
#        ..
# 1300    m
# 1301    m
# 1302    m
# 1303    m
# 1304    m
# Name: unit_of_measurement, Length: 1126, dtype: object

# %%
df = df[df.Region != 'NaN']

# %%
df.head
# Out:
# <bound method NDFrame.head of       Place Country.of.Origin       Altitude                           Region  \
# 0         1          Ethiopia      1950-2200                     guji-hambela
# 1         2          Ethiopia      1950-2200                     guji-hambela
# 2         3         Guatemala  1600 - 1800 m                              NaN
# 3         4          Ethiopia      1800-2200                           oromia
# 4         5          Ethiopia      1950-2200                     guji-hambela
# ...     ...               ...            ...                              ...
# 1300   1302          Honduras      1450 msnm                          marcala
# 1301   1303          Honduras      1450 msnm                          marcala
# 1302   1304            Mexico            900               juchique de ferrer
# 1303   1305             Haiti          ~350m  department d'artibonite , haiti
# 1304   1306         Nicaragua           1100                           jalapa
#
# ...

# %%
print(df)
# Out:
#       Place Country.of.Origin       Altitude                           Region  \
# 0         1          Ethiopia      1950-2200                     guji-hambela
# 1         2          Ethiopia      1950-2200                     guji-hambela
# 2         3         Guatemala  1600 - 1800 m                              NaN
# 3         4          Ethiopia      1800-2200                           oromia
# 4         5          Ethiopia      1950-2200                     guji-hambela
# ...     ...               ...            ...                              ...
# 1300   1302          Honduras      1450 msnm                          marcala
# 1301   1303          Honduras      1450 msnm                          marcala
# 1302   1304            Mexico            900               juchique de ferrer
# 1303   1305             Haiti          ~350m  department d'artibonite , haiti
# 1304   1306         Nicaragua           1100                           jalapa
#
# ...

# %%
df.to_excel("output.xlsx")

# %%
df = df[df.Region.notnull()]

# %%
print(df)
# Out:
#       Place Country.of.Origin   Altitude                           Region  \
# 0         1          Ethiopia  1950-2200                     guji-hambela
# 1         2          Ethiopia  1950-2200                     guji-hambela
# 3         4          Ethiopia  1800-2200                           oromia
# 4         5          Ethiopia  1950-2200                     guji-hambela
# 7         8          Ethiopia  1570-1700                           oromia
# ...     ...               ...        ...                              ...
# 1300   1302          Honduras  1450 msnm                          marcala
# 1301   1303          Honduras  1450 msnm                          marcala
# 1302   1304            Mexico        900               juchique de ferrer
# 1303   1305             Haiti      ~350m  department d'artibonite , haiti
# 1304   1306         Nicaragua       1100                           jalapa
#
#                       In.Country.Partner Harvest.Year          Grading.Date  \
# ...

# %%
df = df[df.altitude_mean_meters.notnull()]

# %%
df.set_index('Place')
# Out:
#       Country.of.Origin   Altitude                           Region  \
# Place
# 1              Ethiopia  1950-2200                     guji-hambela
# 2              Ethiopia  1950-2200                     guji-hambela
# 4              Ethiopia  1800-2200                           oromia
# 5              Ethiopia  1950-2200                     guji-hambela
# 8              Ethiopia  1570-1700                           oromia
# ...                 ...        ...                              ...
# 1302           Honduras  1450 msnm                          marcala
# 1303           Honduras  1450 msnm                          marcala
# 1304             Mexico        900               juchique de ferrer
# 1305              Haiti      ~350m  department d'artibonite , haiti
# 1306          Nicaragua       1100                           jalapa
#
#                        In.Country.Partner Harvest.Year          Grading.Date  \
# Place
# ...

# %%
df.to_excel("output.xlsx")

# %%
df.drop('Altitude' ,1)
# Out:
#       Place Country.of.Origin                           Region  \
# 0         1          Ethiopia                     guji-hambela
# 1         2          Ethiopia                     guji-hambela
# 3         4          Ethiopia                           oromia
# 4         5          Ethiopia                     guji-hambela
# 7         8          Ethiopia                           oromia
# ...     ...               ...                              ...
# 1300   1302          Honduras                          marcala
# 1301   1303          Honduras                          marcala
# 1302   1304            Mexico               juchique de ferrer
# 1303   1305             Haiti  department d'artibonite , haiti
# 1304   1306         Nicaragua                           jalapa
#
#                       In.Country.Partner Harvest.Year          Grading.Date  \
# 0     METAD Agricultural Development plc         2014       April 4th, 2015
# ...

# %%
print(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-2a851eda2e88> in <module>
# ----> 1 print(df)
#
# NameError: name 'df' is not defined

# %%
import pandas as pd

df = pd.read_excel('output.xlsx')
df = df.set_index('Place')

df = df.drop('Altitude' ,1)

# %%
print(df)
# Out:
#        Unnamed: 0 Country.of.Origin                           Region  \
# Place
# 1               0          Ethiopia                     guji-hambela
# 2               1          Ethiopia                     guji-hambela
# 4               3          Ethiopia                           oromia
# 5               4          Ethiopia                     guji-hambela
# 8               7          Ethiopia                           oromia
# ...           ...               ...                              ...
# 1302         1300          Honduras                          marcala
# 1303         1301          Honduras                          marcala
# 1304         1302            Mexico               juchique de ferrer
# 1305         1303             Haiti  department d'artibonite , haiti
# 1306         1304         Nicaragua                           jalapa
#
#                        In.Country.Partner Harvest.Year          Grading.Date  \
# Place
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-4-0f94466193df> in <module>
# ----> 1 df = df.set_index('Place')
#
# D:\Anaconda\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4301
#    4302         if missing:
# -> 4303             raise KeyError(f"None of {missing} are in the columns")
#    4304
#    4305         if inplace:
#
# KeyError: "None of ['Place'] are in the columns"

# %%
df = df.drop('unit_' ,1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-f0904b6d5a40> in <module>
# ----> 1 df = df.drop('unit_' ,1)
#
# D:\Anaconda\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3988                 weight  1.0     0.8
#    3989         """
# -> 3990         return super().drop(
#    3991             labels=labels,
#    3992             axis=axis,
#
# D:\Anaconda\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# D:\Anaconda\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
# ...

# %%
df = df.drop('unit_of_measurement' ,1)

# %%
df.to_excel("output.xlsx")
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# D:\Anaconda\lib\site-packages\xlsxwriter\workbook.py in close(self)
#     315             try:
# --> 316                 self._store_workbook()
#     317             except IOError as e:
#
# D:\Anaconda\lib\site-packages\xlsxwriter\workbook.py in _store_workbook(self)
#     631         except IOError as e:
# --> 632             raise e
#     633
#
# D:\Anaconda\lib\site-packages\xlsxwriter\workbook.py in _store_workbook(self)
#     628         try:
# --> 629             xlsx_file = ZipFile(self.filename, "w", compression=ZIP_DEFLATED,
#     630                                 allowZip64=self.allow_zip64)
#
# D:\Anaconda\lib\zipfile.py in __init__(self, file, mode, compression, allowZip64, compresslevel, strict_timestamps)
#    1249                 try:
# -> 1250                     self.fp = io.open(file, filemode)
# ...

# %%
df.to_excel("output.xlsx")
